# %%
import pandas as pd

# %%
df = pd.read_csv('../data/addresses.csv')
df
# Out:
#               First Name Last Name  Age                           Address  \
# 0                   John       Doe   52                 120 jefferson st.
# 1                   Jack  McGinnis   23                      220 hobo Av.
# 2          John "Da Man"    Repici   38                 120 Jefferson St.
# 3                Stephen     Tyler   96  7452 Terrace "At the Plaza" road
# 4                    NaN  Blankman   14                               NaN
# 5  Joan "the bone", Anne       Jet   56               9th, at Terrace plc
#
#           City State    Zip
# 0    Riverside    NJ   8075
# 1        Phila    PA   9119
# 2    Riverside    NJ   8075
# 3     SomeTown    SD  91234
# 4     SomeTown    SD    298
# 5  Desert City    CO    123

# %%
df["FULLNAME"] = df["First Name"] + " " + df["Last Name"]
df["FULLNAME_lower"] = df["FULLNAME"].str.lower()
df
# Out:
#               First Name Last Name  Age                           Address  \
# 0                   John       Doe   52                 120 jefferson st.
# 1                   Jack  McGinnis   23                      220 hobo Av.
# 2          John "Da Man"    Repici   38                 120 Jefferson St.
# 3                Stephen     Tyler   96  7452 Terrace "At the Plaza" road
# 4                    NaN  Blankman   14                               NaN
# 5  Joan "the bone", Anne       Jet   56               9th, at Terrace plc
#
#           City State    Zip                   FULLNAME  \
# 0    Riverside    NJ   8075                   John Doe
# 1        Phila    PA   9119              Jack McGinnis
# 2    Riverside    NJ   8075       John "Da Man" Repici
# 3     SomeTown    SD  91234              Stephen Tyler
# 4     SomeTown    SD    298                        NaN
# 5  Desert City    CO    123  Joan "the bone", Anne Jet
#
#               FULLNAME_lower
# 0                   john doe
# 1              jack mcginnis
# 2       john "da man" repici
# 3              stephen tyler
# 4                        NaN
# 5  joan "the bone", anne jet
