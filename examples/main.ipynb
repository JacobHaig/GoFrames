# %%
import pandas as pd

# %%
df = pd.read_csv('addresses.csv',header=None)
df
# Out:
#                        0         1                                 2  \
# 0                   John       Doe                 120 jefferson st.
# 1                   Jack  McGinnis                      220 hobo Av.
# 2          John "Da Man"    Repici                 120 Jefferson St.
# 3                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 4                    NaN  Blankman                               NaN
# 5  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#              3    4      5
# 0    Riverside   NJ   8075
# 1        Phila   PA   9119
# 2    Riverside   NJ   8075
# 3     SomeTown   SD  91234
# 4     SomeTown   SD    298
# 5  Desert City   CO    123

# %%
df["FULLNAME"] = df[0] + " " + df[1]
df["FULLNAME_lower"] = df["FULLNAME"].str.lower()
df
# Out:
#                        0         1                                 2  \
# 0                   John       Doe                 120 jefferson st.
# 1                   Jack  McGinnis                      220 hobo Av.
# 2          John "Da Man"    Repici                 120 Jefferson St.
# 3                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 4                    NaN  Blankman                               NaN
# 5  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#              3    4      5                   FULLNAME  \
# 0    Riverside   NJ   8075                   John Doe
# 1        Phila   PA   9119              Jack McGinnis
# 2    Riverside   NJ   8075       John "Da Man" Repici
# 3     SomeTown   SD  91234              Stephen Tyler
# 4     SomeTown   SD    298                        NaN
# 5  Desert City   CO    123  Joan "the bone", Anne Jet
#
#               FULLNAME_lower
# 0                   john doe
# 1              jack mcginnis
# ...
